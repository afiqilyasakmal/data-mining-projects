# %% [markdown]
# # Online Article Popularity

# %%
import pandas as pd

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("./online_artikel_train.csv")

df
# Out:
#              id  timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0          id_1      288.0             9.0             362.0         0.577640
# 1          id_2      623.0             8.0             306.0         0.571429
# 2          id_3      315.0             8.0             536.0         0.536398
# 3          id_4      488.0            12.0            1050.0         0.467695
# 4          id_5      609.0            10.0             399.0         0.503759
# ...         ...        ...             ...               ...              ...
# 29638  id_29639      318.0             9.0            1603.0         0.418399
# 29639  id_29640       79.0            12.0             705.0         0.532951
# 29640  id_29641       45.0            13.0             452.0         0.557110
# 29641  id_29642      265.0            11.0            1687.0         0.403488
# 29642  id_29643      267.0            11.0               0.0         0.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29643 entries, 0 to 29642
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            29643 non-null  object
#  1   timedelta                     29643 non-null  float64
#  2   n_tokens_title                29643 non-null  float64
#  3   n_tokens_content              29643 non-null  float64
#  4   n_unique_tokens               29643 non-null  float64
#  5   n_non_stop_words              29643 non-null  float64
#  6   n_non_stop_unique_tokens      29643 non-null  float64
#  7   num_hrefs                     29643 non-null  float64
#  8   num_self_hrefs                29643 non-null  float64
#  9   num_imgs                      29643 non-null  float64
#  10  num_videos                    29643 non-null  float64
#  11  average_token_length          29643 non-null  float64
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Modeling

# %% [markdown]
# ## 5 Used Model (or more)

# %% [markdown]
# ## K-Cross Fold

# %% [markdown]
# ## T-test

# %% [markdown]
# # Evaluation on Test Set

# %%
df_test = pd.read_csv("./online_artikel_test.csv")
df_test
# Out:
#              id  timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0      id_29644      322.0             8.0             172.0         0.680723
# 1      id_29645      583.0             8.0             636.0         0.529506
# 2      id_29646      199.0            11.0             421.0         0.595238
# 3      id_29647      329.0            15.0             933.0         0.408210
# 4      id_29648      334.0            10.0             655.0         0.502318
# ...         ...        ...             ...               ...              ...
# 9996   id_39640      623.0            11.0             548.0         0.529630
# 9997   id_39641      179.0             9.0             938.0         0.524946
# 9998   id_39642      366.0            10.0             450.0         0.620536
# 9999   id_39643      414.0            11.0             780.0         0.487710
# 10000  id_39644      568.0            13.0             343.0         0.579412
#
# ...

# %%
'''
- Do the prediction here and store the result into 'res' list
- Expectation: 'res' is a two-dimensional list that stores the result of the prediction
    res = [['id_1', 100], ['id_2', 200], ['id_3', 100]]
'''

res = []

## Code below

print(res)
# Out:
# []
